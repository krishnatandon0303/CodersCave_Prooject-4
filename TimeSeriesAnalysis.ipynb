# %% [markdown]
# ***Importing Librearies***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r"C:\Users\ktand\Downloads\apple.csv", parse_dates= ["Date"], index_col= "Date") #parse_dates is used to make str to Datetimeformat
# Out:
# C:\Users\ktand\AppData\Local\Temp\ipykernel_14692\2559650563.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df= pd.read_csv(r"C:\Users\ktand\Downloads\apple.csv", parse_dates= ["Date"], index_col= "Date") #parse_dates is used to make str to Datetimeformat

# %%
df.head()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107

# %%
df.index
# Out:
# DatetimeIndex(['2017-07-07', '2017-07-06', '2017-07-05', '2017-07-03',
#                '2017-06-30', '2017-06-29', '2017-06-28', '2017-06-27',
#                '2017-06-26', '2017-06-23',
#                ...
#                '2016-07-22', '2016-07-21', '2016-07-20', '2016-07-19',
#                '2016-07-18', '2016-07-15', '2016-07-14', '2016-07-13',
#                '2016-07-12', '2016-07-11'],
#               dtype='datetime64[ns]', name='Date', length=251, freq=None)

# %% [markdown]
# ***Retreving specific dates***

# %%
monthly_stock= df.loc["2017-01"].Close.mean()
monthly_stock
# Out:
# np.float64(119.57000000000001)

# %% [markdown]
# Plot the original time series data

# %%
plt.figure(figsize=(10,6))
plt.plot(df['Close'])
plt.title('Original Time Series Data')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# %% [markdown]
# Getting monthly average of apple stock price

# %%
df.Close.resample("M").mean()
# Out:
# C:\Users\ktand\AppData\Local\Temp\ipykernel_20124\992377420.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.Close.resample("M").mean()
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# 2016-12-31    114.335714
# 2017-01-31    119.570000
# 2017-02-28    133.713684
# 2017-03-31    140.617826
# 2017-04-30    142.886842
# 2017-05-31    152.227727
# 2017-06-30    147.831364
# 2017-07-31    143.625000
# Freq: ME, Name: Close, dtype: float64

# %% [markdown]
# ***Resampling***

# %% [markdown]
# plotting chart of the monthly average stock price of apple

# %%
# %matplotlib inline
df.Close.resample("M").mean().plot(kind = 'line')
# Out:
# C:\Users\ktand\AppData\Local\Temp\ipykernel_20124\1028978957.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.Close.resample("M").mean().plot(kind = 'line')
# <Axes: xlabel='Date'>

# %% [markdown]
# resampling DataFrame to a daily frequency and filling missing values using Pad method

# %%
df.asfreq("D",method= "pad")
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# ...            ...     ...     ...     ...       ...
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-07-04  143.69  144.79  142.72  144.09  21569557
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
#
# [362 rows x 5 columns]

# %% [markdown]
# Resampling DataFrame to a weekly frequency and filling missing values using Pad method

# %%
df.asfreq("W",method= "pad")
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2016-07-17   98.70  100.13   98.60   99.83  36493867
# 2016-07-24   98.25   98.84   96.92   97.34  40382921
# 2016-07-31  104.41  106.15  104.41  106.05  38167871
# 2016-08-07  107.52  108.37  107.16  108.37  28037220
# 2016-08-14  108.14  109.54  108.08  109.48  25868209
# 2016-08-21  108.86  109.10  107.85  108.51  25820230
# 2016-08-28  106.62  107.44  106.29  106.82  24970300
# 2016-09-04  107.90  108.30  107.51  107.70  26880391
# 2016-09-11  102.65  105.72  102.53  105.44  45292770
# 2016-09-18  115.19  116.18  113.25  113.58  47023046
# 2016-09-25  111.64  113.39  111.55  112.88  29869442
# 2016-10-02  112.71  113.05  112.28  112.52  21701760
# 2016-10-09  115.02  116.75  114.72  116.05  36235956
# 2016-10-16  117.33  117.84  116.78  117.55  23624896
# 2016-10-23  117.10  117.74  117.00  117.65  23538673
# 2016-10-30  113.65  114.23  113.20  113.54  26419398
# 2016-11-06  110.08  110.51  109.46  110.41  32560000
# ...

# %% [markdown]
# ***Handling holidays***

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
usb = CustomBusinessDay(calendar= USFederalHolidayCalendar())
usb

# %%
pd.date_range(start = '01-01-2017',end = '07-10-2017',freq = usb)
# Out:
# DatetimeIndex(['2017-01-03', '2017-01-04', '2017-01-05', '2017-01-06',
#                '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-17',
#                ...
#                '2017-06-26', '2017-06-27', '2017-06-28', '2017-06-29',
#                '2017-06-30', '2017-07-03', '2017-07-05', '2017-07-06',
#                '2017-07-07', '2017-07-10'],
#               dtype='datetime64[ns]', length=131, freq='C')

# %% [markdown]
# ***Calculate moving averages***

# %%
df['MA_7'] = df['Close'].rolling(window=7).mean()
df['MA_30'] = df['Close'].rolling(window=30).mean()
df
# Out:
#               Open    High     Low   Close    Volume       MA_7       MA_30
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712        NaN         NaN
# 2017-07-06  143.02  143.50  142.41  142.73  24128782        NaN         NaN
# 2017-07-05  143.69  144.79  142.72  144.09  21569557        NaN         NaN
# 2017-07-03  144.88  145.30  143.10  143.50  14277848        NaN         NaN
# 2017-06-30  144.45  144.96  143.78  144.02  23024107        NaN         NaN
# ...            ...     ...     ...     ...       ...        ...         ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990  99.124286  105.082667
# 2016-07-14   97.39   98.99   97.32   98.79  38918997  99.331429  104.790000
# 2016-07-13   97.41   97.67   96.84   96.87  25892171  99.075714  104.418000
# 2016-07-12   97.17   97.70   97.12   97.42  24167463  98.788571  104.037000
# 2016-07-11   96.75   97.65   96.73   96.98  23794945  98.362857  103.652667
#
# [251 rows x 7 columns]

# %% [markdown]
# ***Plot moving averages***

# %%
# Plot moving averages
plt.figure(figsize=(10,6))
plt.plot(df['Close'], label='Close Price')
plt.plot(df['MA_7'], label='7-Day Moving Average')
plt.plot(df['MA_30'], label='30-Day Moving Average')
plt.title('Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ***Calculate daily returns***

# %%
df['Return'] = df['Close'].pct_change()
df
# Out:
#               Open    High     Low   Close    Volume       MA_7       MA_30  \
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712        NaN         NaN
# 2017-07-06  143.02  143.50  142.41  142.73  24128782        NaN         NaN
# 2017-07-05  143.69  144.79  142.72  144.09  21569557        NaN         NaN
# 2017-07-03  144.88  145.30  143.10  143.50  14277848        NaN         NaN
# 2017-06-30  144.45  144.96  143.78  144.02  23024107        NaN         NaN
# ...            ...     ...     ...     ...       ...        ...         ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990  99.124286  105.082667
# 2016-07-14   97.39   98.99   97.32   98.79  38918997  99.331429  104.790000
# 2016-07-13   97.41   97.67   96.84   96.87  25892171  99.075714  104.418000
# 2016-07-12   97.17   97.70   97.12   97.42  24167463  98.788571  104.037000
# 2016-07-11   96.75   97.65   96.73   96.98  23794945  98.362857  103.652667
#
#               Return
# Date
# ...

# %% [markdown]
# ***Plot daily return***

# %%
plt.figure(figsize=(10,6))
plt.plot(df['Return'])
plt.title('Daily Returns')
plt.xlabel('Date')
plt.ylabel('Return')
plt.show()

# %% [markdown]
# ***Calculate cumulative returns***

# %%
df['Cumulative Return'] = (1 + df['Return']).cumprod()
df
# Out:
#               Open    High     Low   Close    Volume       MA_7       MA_30  \
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712        NaN         NaN
# 2017-07-06  143.02  143.50  142.41  142.73  24128782        NaN         NaN
# 2017-07-05  143.69  144.79  142.72  144.09  21569557        NaN         NaN
# 2017-07-03  144.88  145.30  143.10  143.50  14277848        NaN         NaN
# 2017-06-30  144.45  144.96  143.78  144.02  23024107        NaN         NaN
# ...            ...     ...     ...     ...       ...        ...         ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990  99.124286  105.082667
# 2016-07-14   97.39   98.99   97.32   98.79  38918997  99.331429  104.790000
# 2016-07-13   97.41   97.67   96.84   96.87  25892171  99.075714  104.418000
# 2016-07-12   97.17   97.70   97.12   97.42  24167463  98.788571  104.037000
# 2016-07-11   96.75   97.65   96.73   96.98  23794945  98.362857  103.652667
#
#               Return  Cumulative Return
# Date
# ...

# %% [markdown]
# ***Plot cumulative returns***

# %%
plt.figure(figsize=(10,6))
plt.plot(df['Cumulative Return'])
plt.title('Cumulative Returns')
plt.xlabel('Date')
plt.ylabel('Cumulative Return')
plt.show()
